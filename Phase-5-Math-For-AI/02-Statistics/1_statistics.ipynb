# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = [10, 12, 11, 13, 1000]

variance = np.var(data)
std_dev = np.std(data) 

print("Variance: ", variance)
print("Standard Deviation: ", std_dev)
# Out:
# Variance:  156342.15999999997
# Standard Deviation:  395.4012645402136

# %% [markdown]
# # Outlier Detection (IQR + Box Plot thinking)

# %%
data = np.array([12, 15, 14, 10, 18, 21, 19, 17, 16, 200])

# IQR method
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1 

lower_bound = Q1 - 1.5 * IQR 
upper_bound = Q3 + 1.5 * IQR 

outliers = [x for x in data if x < lower_bound or x > upper_bound]

print("Outliers: ", outliers)
# Out:
# Outliers:  [np.int64(200)]

# %% [markdown]
# ---

# %%
d = [10, 12, 14, 16, 18, 20, 22] 

Q1 = np.percentile(d, 25)
Q2 = np.percentile(d, 50)
Q3 = np.percentile(d, 75)

IQR = Q3 - Q1

l_b = Q1 - 1.5 * IQR 
u_b = Q3 + 1.5 * IQR

outliers = [x for x in d if x < l_b or x > u_b] 
print("outliers: ", outliers)
print("Q1: ", Q1)
print("Q2: ", Q2)
print("Q3: ", Q3)
print("IQR: ", IQR)
print("lower bound: ", l_b)
print("Upper bound: ", u_b)

plt.boxplot(d)
plt.title("Understanding Outliers from data") 
plt.ylabel("values")
plt.grid() 
plt.show()
# Out:
# outliers:  []
# Q1:  13.0
# Q2:  16.0
# Q3:  19.0
# IQR:  6.0
# lower bound:  4.0
# Upper bound:  28.0

# %% [markdown]
# # Skewness Analysis

# %%
data = pd.Series([12, 15, 14, 10, 18, 21, 19, 17, 16, 200])

print(data.skew())
print("Mean:", data.mean())
print("Median:", data.median())
# Out:
# 3.143758499766234
# Mean: 34.2
# Median: 16.5
