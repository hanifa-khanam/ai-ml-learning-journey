# %% [markdown]
# ## **`Pandas Filtering Data`**
#
# - Filtering = selecting rows that satisfy a condition

# %%
import pandas as pd

# %%
df = pd.read_csv("globalAirQuality.csv") 

df
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df[(df["aqi"] > 100) & (df["temperature"] > 30)]
# Out:
#                         timestamp country      city  latitude  longitude  \
# 6      2025-11-05 00:25:17.554219      US  New York    40.713    -74.006
# 7      2025-11-05 01:25:17.554219      US  New York    40.713    -74.006
# 14     2025-11-05 08:25:17.554219      US  New York    40.713    -74.006
# 17     2025-11-05 11:25:17.554219      US  New York    40.713    -74.006
# 25     2025-11-05 19:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17947  2025-11-17 13:25:17.554219      CH    Zurich    47.377      8.542
# 17950  2025-11-17 16:25:17.554219      CH    Zurich    47.377      8.542
# 17975  2025-11-18 17:25:17.554219      CH    Zurich    47.377      8.542
# 17976  2025-11-18 18:25:17.554219      CH    Zurich    47.377      8.542
# 17991  2025-11-19 09:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df[ df["aqi"] > 100] [["city", "aqi"]]
# Out:
#            city  aqi
# 0      New York  108
# 3      New York  158
# 6      New York  155
# 7      New York  115
# 8      New York  121
# ...         ...  ...
# 17991    Zurich  104
# 17993    Zurich  153
# 17995    Zurich  103
# 17996    Zurich  105
# 17997    Zurich  122
#
# [9721 rows x 2 columns]

# %% [markdown]
# | Filtering Type                 | Purpose                   | General Syntax                    | Example                                        |
# | ------------------------------ | ------------------------- | --------------------------------- | ---------------------------------------------- |
# | **Single condition**           | Filter by one rule        | `df[df["col"] op value]`          | `df[df["Age"] > 20]`                           |
# | **AND condition**              | All conditions true       | `df[(cond1) & (cond2)]`           | `df[(df["Age"] > 20) & (df["Marks"] > 85)]`   |
# | **OR condition**               | Any condition true        | `df[(cond1) \| (cond2)]`          | `df[(df["City"]=="Lahore") \| (df["City"]=="Karachi")]` |
# | **NOT condition**              | Exclude values            | `df[~condition]`                  | `df[~(df["City"]=="Karachi")]`                 |
# | **Select columns with filter** | Filter + column selection | `df.loc[condition, cols]`         | `df.loc[df["Marks"]>80, ["Name","Marks"]]`     |
# | **Multiple values**            | Match from list           | `df[df["col"].isin(list)]`        | `df[df["City"].isin(["Lahore","Islamabad"])]`  |
# | **String contains**            | Text filtering            | `df[df["col"].str.contains("x")]` | `df[df["Name"].str.contains("a", case=False)]` |
# | **Starts / ends with**         | Prefix / suffix match     | `df["col"].str.startswith()`      | `df[df["Name"].str.startswith("A")]`           |
# | **Missing values**             | NaN filtering             | `df["col"].isna()`                | `df[df["Age"].isna()]`                         |
# | **Non-missing values**         | Valid data                | `df["col"].notna()`               | `df[df["Age"].notna()]`                        |
# | **Query method**               | Clean readable filter     | `df.query("condition")`           | `df.query("Age > 20 and Marks > 85")`          |
# | **Random sample**              | Random rows               | `df.sample(n)`                    | `df.sample(5)`                                 |

# %%
# single condition
df[df["aqi"] > 100]
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 6      2025-11-05 00:25:17.554219      US  New York    40.713    -74.006
# 7      2025-11-05 01:25:17.554219      US  New York    40.713    -74.006
# 8      2025-11-05 02:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17991  2025-11-19 09:25:17.554219      CH    Zurich    47.377      8.542
# 17993  2025-11-19 11:25:17.554219      CH    Zurich    47.377      8.542
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
# AND condition
df[(df["aqi"] > 100) & (df["temperature"] > 30)]
# Out:
#                         timestamp country      city  latitude  longitude  \
# 6      2025-11-05 00:25:17.554219      US  New York    40.713    -74.006
# 7      2025-11-05 01:25:17.554219      US  New York    40.713    -74.006
# 14     2025-11-05 08:25:17.554219      US  New York    40.713    -74.006
# 17     2025-11-05 11:25:17.554219      US  New York    40.713    -74.006
# 25     2025-11-05 19:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17947  2025-11-17 13:25:17.554219      CH    Zurich    47.377      8.542
# 17950  2025-11-17 16:25:17.554219      CH    Zurich    47.377      8.542
# 17975  2025-11-18 17:25:17.554219      CH    Zurich    47.377      8.542
# 17976  2025-11-18 18:25:17.554219      CH    Zurich    47.377      8.542
# 17991  2025-11-19 09:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
# or condition
df[(df["city"]== "Taxila") | (df["temperature"] > 40)]
# Out:
# Empty DataFrame
# Columns: [timestamp, country, city, latitude, longitude, pm25, pm10, no2, so2, o3, co, aqi, temperature, humidity, wind_speed]
# Index: []

# %%
#not condition
df[~((df["country"]=="USA") & (df["city"]=="NewYork")) ]
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
# Select columns with filters
df.loc[df["aqi"] > 200, ["country", "city", "temperature", "aqi"]]
# Out:
#       country      city  temperature  aqi
# 745        GB    London       19.055  214
# 8941       JP     Osaka       15.277  204
# 12956      NZ  Auckland       14.872  225
# 14555      PH    Manila       11.027  206
# 17458      FI  Helsinki       34.420  202
# 17529      FI  Helsinki       25.795  231
# 17815      CH    Zurich       20.883  203

# %% [markdown]
# ## **`Filtering Data using query()`**
#
# `query()` lets you filter rows using **SQL-like, English-style conditions** instead of boolean brackets.
#
# General syntax: `df.query("condition")`
#
# `query()` rules:
#
# - Expression as a string
# - Column based reference
# - Backticks for col_name with space or special chars
# - Operators (&, |, ~, >=, >, <=, <, == etc.)
# - @ to reference Python vars
# - chained comparison

# %%
df.query("aqi > 160")
# Out:
#                         timestamp country      city  latitude  longitude  \
# 81     2025-11-08 03:25:17.554219      US  New York    40.713    -74.006
# 112    2025-11-09 10:25:17.554219      US  New York    40.713    -74.006
# 189    2025-11-12 15:25:17.554219      US  New York    40.713    -74.006
# 194    2025-11-12 20:25:17.554219      US  New York    40.713    -74.006
# 197    2025-11-12 23:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17821  2025-11-12 07:25:17.554219      CH    Zurich    47.377      8.542
# 17822  2025-11-12 08:25:17.554219      CH    Zurich    47.377      8.542
# 17885  2025-11-14 23:25:17.554219      CH    Zurich    47.377      8.542
# 17886  2025-11-15 00:25:17.554219      CH    Zurich    47.377      8.542
# 17888  2025-11-15 02:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df.query("aqi > 100 & temperature > 35") [["city", "aqi"]]
# Out:
#            city  aqi
# 6      New York  155
# 7      New York  115
# 17     New York  127
# 82     New York  122
# 105    New York  127
# ...         ...  ...
# 17866    Zurich  140
# 17874    Zurich  146
# 17883    Zurich  129
# 17902    Zurich  105
# 17950    Zurich  140
#
# [909 rows x 2 columns]

# %%
aqi_value = 100
df.query("aqi > @aqi_value & temperature > 35") [["city", "aqi"]]
# Out:
#            city  aqi
# 6      New York  155
# 7      New York  115
# 17     New York  127
# 82     New York  122
# 105    New York  127
# ...         ...  ...
# 17866    Zurich  140
# 17874    Zurich  146
# 17883    Zurich  129
# 17902    Zurich  105
# 17950    Zurich  140
#
# [909 rows x 2 columns]
