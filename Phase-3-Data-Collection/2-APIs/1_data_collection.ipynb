# %% [markdown]
# ## **`Working with APIs`**

# %%
import requests

# %%
URL = "https://potterapi-fedeperin.vercel.app/en/spells"

# %%
res = requests.get(URL)

# %%
res
# Out:
# <Response [200]>

# %%
data = res.json()

# %%
import pandas as pd

# %%
df = pd.json_normalize(data[:])

# %%
df
# Out:
#                            spell  \
# 0                          Accio
# 1                        Glisseo
# 2                      Impervius
# 3   Wingardium Leviosa/Locomotor
# 4                      Scourgify
# ..                           ...
# 67               Fiendfyre Curse
# 68                 Tarantallegra
# 69                    Morsmordre
# 70                  Sectumsempra
# 71                        Crucio
#
#                                                   use  index
# 0                                     Summoning charm      0
# 1                      Turns a staircase into a slide      1
# 2   Protects caster from a variety of substances, ...      2
# 3                                   Levitates objects      3
# 4                                       Cleans things      4
# ..                                                ...    ...
# 67                                  Makes cursed fire     67
# 68                             Forces target to dance     68
# ...

# %%
df[0: 11]
# Out:
#                            spell  \
# 0                          Accio
# 1                        Glisseo
# 2                      Impervius
# 3   Wingardium Leviosa/Locomotor
# 4                      Scourgify
# 5                         Portus
# 6                     Orchideous
# 7                          Lumos
# 8                         Reparo
# 9                        Reducio
# 10                          Pack
#
#                                                   use  index
# 0                                     Summoning charm      0
# 1                      Turns a staircase into a slide      1
# 2   Protects caster from a variety of substances, ...      2
# 3                                   Levitates objects      3
# 4                                       Cleans things      4
# 5                                   Creates a portkey      5
# 6                      Grows flowers from end of wand      6
# 7                               Makes wand emit light      7
# ...

# %%
df.head()
# Out:
#                           spell  \
# 0                         Accio
# 1                       Glisseo
# 2                     Impervius
# 3  Wingardium Leviosa/Locomotor
# 4                     Scourgify
#
#                                                  use  index
# 0                                    Summoning charm      0
# 1                     Turns a staircase into a slide      1
# 2  Protects caster from a variety of substances, ...      2
# 3                                  Levitates objects      3
# 4                                      Cleans things      4

# %%
df.tail()
# Out:
#               spell                        use  index
# 67  Fiendfyre Curse          Makes cursed fire     67
# 68    Tarantallegra     Forces target to dance     68
# 69       Morsmordre     Conjures the Dark Mark     69
# 70     Sectumsempra  Causes severe lacerations     70
# 71           Crucio        Causes immense pain     71
